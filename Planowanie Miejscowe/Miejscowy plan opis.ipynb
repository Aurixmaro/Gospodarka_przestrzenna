# %%
Miejscowy plan zagospodarowania przestrzennego

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN8, MN11, 
Kolor: jasnobrązowy
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 30%
Geometria dachów: wielospadowe o jednakowym nachyleniu 30°-45°
Wysokość budynków: maksymalnie 2 kondygnacje nadziemne, 8m
Nakazy: drogi wewnętrzne, dojścia
Zakazy: garaże
Dopuszczenia: zabudowa usługowa  

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN9, MN13
Kolor: jasnobrązowy
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 30%
- wskaźnik intensywności zabudowy: 0.6
- min. powierzchnia biologicznie czynna: 50%
Geometria dachów: dwuspadowe o jednakowym nachyleniu 45°, z wysuniętymi okapami, z możliwością realizacji lukarn,  okien dachowych, zadaszeń nad wejściem, itp.
Wysokość budynków: maksymalnie 3 kondygnacje nadziemne, 12m
Nakazy: urządzenia i sieci infrastruktury technicznej
Zakazy:  wiaty
Dopuszczenia: zabudowa usługowa  obiekty, drogi wewnętrzne, dojścia, miejsca parkingowe ,budynki gospodarcze, garaże, zieleń urządzona.

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN1, MN 18,  MN20
Kolor: jasnobrązowy
Linia zabudowy: Nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50%
- wskaźnik intensywności zabudowy: 1,5
- min. powierzchnia biologicznie czynna: 30%
Geometria dachów: wielospadowe
Wysokość budynków: 12m
Nakazy: drogi wewnętrzne
Zakazy: budynki gospodarcze
Dopuszczenia: zabudowa usługowa  

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN9, MN13, MN10, MN18
Kolor: jasnobrązowy
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 30%
- wskaźnik intensywności zabudowy: 0.6
- min. powierzchnia biologicznie czynna: 50%
Geometria dachów: dwuspadowe o jednakowym nachyleniu 45°, z wysuniętymi okapami, z możliwością realizacji lukarn,  okien dachowych, zadaszeń nad wejściem, itp.
Wysokość budynków: maksymalnie 3 kondygnacje nadziemne, 12m
Nakazy: urządzenia i sieci infrastruktury technicznej
Zakazy:  wiaty
Dopuszczenia: zabudowa usługowa  obiekty, drogi wewnętrzne, dojścia, miejsca parkingowe ,budynki gospodarcze, garaże, zieleń urządzona.

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN3, MN4, MN5, MN12, MN14, MN15, MN17, MN19, MN21
Kolor: jasnobrązowy
Linia zabudowy: Nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 30%
- wskaźnik intensywności zabudowy: 0.9
- min. powierzchnia biologicznie czynna: 5%
Geometria dachów: dwuspadowe lub wielospadowe o jednakowym nachyleniu 30°-45°, z wysuniętymi okapami, z możliwością realizacji lukarn,  okien dachowych, zadaszeń nad wejściem, itp.
Wysokość budynków: maksymalnie 3 kondygnacje nadziemne, 12m
Nakazy: urządzenia i sieci infrastruktury technicznej
Zakazy:  wiaty
Dopuszczenia: zabudowa usługowa  obiekty, drogi wewnętrzne, dojścia, miejsca parkingowe ,budynki gospodarcze, garaże, zieleń urządzona.

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej jednorodzinnej
Symbol: MN6, MN7, MN16, 
Kolor: jasnobrązowy
Linia zabudowy: Nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50%
- wskaźnik intensywności zabudowy: 1,5
- min. powierzchnia biologicznie czynna: 30%
Geometria dachów: wielospadowe
Wysokość budynków: 12m
Nakazy: jednakowy kolor elewacji
Zakazy: udostępnianie pod działalność usługową, dachy z eternitem
Dopuszczenia: wiaty, garaże, drogi dojazdowe

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW1, 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 40%
- wskaźnik intensywności zabudowy: 1.6
- min. powierzchnia biologicznie czynna: 20%
Geometria dachów: płaskie
Wysokość budynków: 16m
Nakazy: wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie
Zakazy: zakaz lokalizacji parkingów z wyłączeniem rowerowych
Dopuszczenia: funkcji innych niż mieszkaniowe na parterze 
Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW2, 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 40%
- wskaźnik intensywności zabudowy: 1.6
- min. powierzchnia biologicznie czynna: 20%
Geometria dachów: płaskie
Wysokość budynków: 16m
Nakazy: Warsztat Samochodwy, wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie, 
Zakazy: zakaz lokalizacji parkingów z wyłączeniem rowerowych
Dopuszczenia: funkcji innych niż mieszkaniowe na drugiej kondygnacji

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW3, MW11 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50%
- wskaźnik intensywności zabudowy: 2
- min. powierzchnia biologicznie czynna: 45%
Geometria dachów: płaskie
Wysokość budynków: 16m
Nakazy: wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie
Zakazy: zakaz lokalizacji parkingów z wyłączeniem rowerowych
Dopuszczenia: funkcji innych niż mieszkaniowe na parterze

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW4, MW8, MW7, MW 17, MW20, MW 21 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  60%
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 20% 
Geometria dachów: płaskie
Wysokość budynków: 12m
Nakazy: Nakaz funkcji usługowych na parterach od strony ulic 
Zakazy: zakaz lokalizacji parkingów z wyłączeniem rowerowych
Dopuszczenia: możliwość zmiany przeznaczenia budynku, wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie



Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW5, MW9, MW14, 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  25%
- wskaźnik intensywności zabudowy: 0.5
- min. powierzchnia biologicznie czynna: 60% 
Geometria dachów: płaskie
Wysokość budynków: 8m
Nakazy: Nakaz wyposażenia budynków z sprzed dla osób niepełnosprawnych w postaci wind 
Zakazy: zakaz lokalizacji parkingów z wyłączeniem rowerowych
Dopuszczenia: zieleń urządzona

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW6, MW12, MW13, MW15, MW16, MW18, MW20, MW22 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  70%
- wskaźnik intensywności zabudowy: 2.1
- min. powierzchnia biologicznie czynna: 10% 
Geometria dachów: płaskie
Wysokość budynków: 12m
Nakazy: urządzenia infrastruktury technicznej,  wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie
Zakazy: zakaz tworzenia miejsc parkingowych
Dopuszczenia: funkcje usługowe na pierwszej kondygnacji

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW23 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  60%
- wskaźnik intensywności zabudowy: 2.8
- min. powierzchnia biologicznie czynna: 30% 
Geometria dachów: dwuspadowe
Wysokość budynków: 16m
Nakazy: urządzenia infrastruktury technicznej,  wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie
Zakazy: zakaz tworzenia miejsc parkingowych
Dopuszczenia: funkcje usługowe na pierwszej kondygnacji

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Symbol: MW24 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  60%
- wskaźnik intensywności zabudowy: 2.8
- min. powierzchnia biologicznie czynna: 30% 
Geometria dachów: dwuspadowe
Wysokość budynków: 16m
Nakazy: urządzenia infrastruktury technicznej,  wyposażenie w urządzenia pomagające osobom niepełnosprawnym: windy, pochylnie
Zakazy: zakaz tworzenia miejsc parkingowych
Dopuszczenia: funkcje usługowe na pierwszej kondygnacji

Przeznaczenie terenu : Tereny zabudowy mieszkaniowej wielorodzinnej
Kolor: ciemnobrązowy
Symbol: MW19, MW25 
Kolor: ciemnobrązowy
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  70%
- wskaźnik intensywności zabudowy: 2.1
- min. powierzchnia biologicznie czynna: 10% 
Geometria dachów: płaskie
Wysokość budynków: 12m
Nakazy: urządzenia infrastruktury technicznej,  
Zakazy: zakaz tworzenia miejsc parkingowych
Dopuszczenia: funkcje usługowe na pierwszej kondygnacji

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol:U7,  U11, U12, U16, U17, U19, U29, U30 
Kolor: Czerwony
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 1.4
- min. powierzchnia biologicznie czynna: 20
Geometria dachów: płaskie lub jednospadowe
Wysokość budynków: 8
Nakazy: wyposażenie w wszelkie urządzenia infrastruktury technicznej
Zakazy: zakaz przeznaczenia inny niż usługowy
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących, możliwość usytuowania reklamy 

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol: U6, U14, U13, U24, U26 , U22, U28
Kolor: Czerwony
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2 
- min. powierzchnia biologicznie czynna: 10 
Geometria dachów: jednospadowe lub płaskie
Wysokość budynków: 12
Nakazy: wyposażenie w wszelkie urządzenia infrastruktury technicznej, funkcje mieszkalne na 2 i 3 kondygnacji
Zakazy: zakaz zakrywania elewacji roślinnością
Dopuszczenia: dopuszcza się realizacje usług innych niż przeznaczenie usług podstawowych 

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol:  U23
Kolor: Czerwony
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2 
- min. powierzchnia biologicznie czynna: 20
Geometria dachów: jednospadowe lub płaskie
Wysokość budynków: 12
Nakazy: nakaz opalania gazowego
Zakazy: zakaz stawiania reklam
Dopuszczenia: dopuszcza się realizacje usług kultury 

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol:U9,  U25 
Kolor: Czerwony
Linia zabudowy: Nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 1.4
- min. powierzchnia biologicznie czynna: 20
Geometria dachów: płaskie lub jednospadowe
Wysokość budynków: 8
Nakazy: wyposażenie w wszelkie urządzenia infrastruktury technicznej
Zakazy: zakaz przeznaczenia inny niż usługowy
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących, możliwość usytuowania reklamy 

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol: U4, U5, U8, U10 
Kolor: Czerwony
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2 
- min. powierzchnia biologicznie czynna: 10 
Geometria dachów: jednospadowe lub płaskie
Wysokość budynków: 12
Nakazy: wyposażenie w wszelkie urządzenia infrastruktury technicznej, możliwość funkcji mieszkalnych
Zakazy: brak
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących, możliwość usytuowania reklamy 

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol: U1, U2, U3
Kolor: Czerwony
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50
- wskaźnik intensywności zabudowy: 2 
- min. powierzchnia biologicznie czynna: 30 
Geometria dachów: nieregularne jednospadowe
Wysokość budynków: 16m
Nakazy:  Dworzec Autobusowy, dworzec kolejowy, Centrum przesiadkowe, parkingi, drogi dojazdowe, ławki, kosze, 
Zakazy: zakaz funkcji biurowych i hotelowych
Dopuszczenia:  mała gastronomia w granicach obiektu nie przekraczająca 30%  powierzchni budynku

Przeznaczenie terenu : Tereny zabudowy usługowej
Symbol: U15,U20, U27, U28
Kolor: Czerwony
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy:  50
- wskaźnik intensywności zabudowy:  1.5
- min. powierzchnia biologicznie czynna:  30
Geometria dachów: jednospadowe
Wysokość budynków: 12m
Nakazy: jednakowy kolor elewacji, funkcje mieszkaniowe a 2 i 3 kondygnacji
Zakazy: zakaz umiejscowienia parkingów z wyjątkiem zaczepów rowerowych
Dopuszczenia:  możliwość stawiania reklam, możliwość prowadzenia dowolnej działalności usługowej na 1 kondygnacji

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US6, US8
Kolor: Kreskowanie zielono-czerwone
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 1.4
- min. powierzchnia biologicznie czynna: 20
Geometria dachów: płaskie lub jednospadowe
Wysokość budynków: 8
Nakazy: jednakowy kolor elewacji
Zakazy: zakazuje się stawiania reklam, płotu wyższego niż 1.5m
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących tj. szatnie, magazyny podręczne o wysokości do 2 kondygnacji, związanych z funkcją podstawową,  możliwość wydzielenia i ogrodzenia terenów rekreacyjno wypoczynkowych

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US7, US11 
Kolor: ciemnobrązowy
Linia zabudowy: Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50%
- wskaźnik intensywności zabudowy: 2
- min. powierzchnia biologicznie czynna: 45%
Geometria dachów: płaskie
Wysokość budynków: 16m
Nakazy: zespoły zamieszkania zbiorowego
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących tj. szatnie, magazyny podręczne o wysokości do 2 kondygnacji, związanych z funkcją podstawową,  możliwość wydzielenia i ogrodzenia terenów rekreacyjno wypoczynkowych,  możliwość lokalizacji basenów, pływalni, lokalizacja placów zabaw.

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US5
Kolor: Czerwony- kreskowany purpurowo
Linia zabudowy: obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2 
- min. powierzchnia biologicznie czynna: 10 
Geometria dachów: jednospadowe lub płaskie
Wysokość budynków: 12
Nakazy: obowiązek podpięcia do infrastruktury technicznej, drogi dojazdowe, parking
Zakazy:  zakaz podpiwniczania budynków
Dopuszczenia: możliwość lokalizacji budynków i budowli związanych z zapleczem noclegowym, drobnymi usługami handlu i gastronomii, basenów

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US9
Kolor: Kreskowanie zielono-czerwone
Linia zabudowy:  Obowiązująca linia zabudowy
Wysokość budynków: Brak
Funkcje : Rynek
Zakazy: Zakaz stawiania miejsc parkingowych i wjazdów na teren rynku
Dopuszczenia: możliwość stawiania ławek, koszy, pojedynczych zadrzewień

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US1, US3
Kolor: Kreskowanie zielono-czerwone
Linia zabudowy:  nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 1.4
- min. powierzchnia biologicznie czynna: 20
Geometria dachów: płaskie lub jednospadowe
Wysokość budynków: 8
Nakazy: jednakowy kolor elewacji
Zakazy: zakazuje się stawiania reklam, płotu wyższego niż 1.5m
Dopuszczenia: możliwość realizacji obiektów kubaturowych towarzyszących tj. szatnie, magazyny podręczne o wysokości do 2 kondygnacji, związanych z funkcją podstawową,  możliwość wydzielenia i ogrodzenia terenów rekreacyjno wypoczynkowych

Przeznaczenie terenu : Tereny sportu i rekreacji
Symbol: US2, US10, US12
Kolor: Kreskowanie zielono-czerwone
Linia zabudowy:  nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 0,7 
- min. powierzchnia biologicznie czynna: 10% 
Geometria dachów: płaskie lub jednospadowe
Wysokość budynków: 4
Nakazy: droga dojazdowa, parking
Zakazy: zakaz podpiwniczania budynków,
Dopuszczenia: wyodrębnienie miejsc palenia ognisk, amfiteatru, ścieżek spacerowych, stanowisk wędkarskich, możliwość lokalizacji budowli związanych z obsługa sportów wodnych: przystanie, pomosty stałe i pływające, hangary i pochylnie

Przeznaczenie terenu : Tereny obiektów handlowych o pow. >2000m2
Symbol: UC3 , UC4
Kolor: Kreskowanie- czerwono-ciemnoszare
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60%
- wskaźnik intensywności zabudowy: 2.4
- min. powierzchnia biologicznie czynna: 10%
Geometria dachów: jednospadowe
Wysokość budynków: 16
Nakazy: gastronomia na ostatniej kondygnacji
Zakazy: płoty wyższe niż 1.5m , zieleń urządzona na elewacji
Dopuszczenia: tereny zabudowy usługowej - usług konsumpcyjnych tj. obiekty handlowe, gastronomiczne oraz, usługi różne (w tym rzemiosło nieprodukcyjne) itp. o powierzchni sprzedaży mniejszej niż 2000m2 .

Przeznaczenie terenu : Tereny obiektów handlowych o pow. >2000m2
Symbol: UC1, UC2
Kolor:  Kreskowanie- czerwono-ciemnoszare
Linia zabudowy:  Nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 70
- wskaźnik intensywności zabudowy: 2.8
- min. powierzchnia biologicznie czynna: 10%
Geometria dachów: Jednospadowe nieregularne
Wysokość budynków: 20
Nakazy: gastronomia na ostatniej kondygnacji
Zakazy: płoty wyższe niż 1.5m , zieleń urządzona na elewacji
Dopuszczenia: tereny zabudowy usługowej - usług konsumpcyjnych tj. obiekty handlowe, gastronomiczne oraz, usługi różne (w tym rzemiosło nieprodukcyjne) itp. o powierzchni sprzedaży mniejszej niż 2000m2 .

Przeznaczenie terenu : Tereny usług kultury
Symbol: UK3,UK5, UK4
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2 
- min. powierzchnia biologicznie czynna: 10 
Geometria dachów: jednospadowe lub płaskie
Wysokość budynków: 12m
Nakazy: parkingi, ścieżki
Zakazy: zakaz budowy zespołów garaży od strony przestrzeni publicznych.
Dopuszczenia: usług konsumpcyjnych kultury  typu: kina, domy kultury, muzea, biblioteki, galerie sztuki, archiwa, usługi artystyczne i rozrywkowe, amfiteatry

Przeznaczenie terenu : Tereny usług kultury
Symbol: UK1, UK2, UK6
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10
Geometria dachów: dwuspadowe
Wysokość budynków: 12m
Nakazy: parkingi, ścieżki
Zakazy: zakaz budowy zespołów garaży od strony przestrzeni publicznych.
Dopuszczenia: usług konsumpcyjnych kultury  typu: kina, domy kultury, muzea, biblioteki, galerie sztuki, archiwa, usługi artystyczne i rozrywkowe, amfiteatry

Przeznaczenie terenu : Tereny usług zdrowia
Symbol:  UZ1, UZ4
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10
Geometria dachów: dwuspadowe
Wysokość budynków: 12m
Nakazy: parkingi, ścieżki
Zakazy: zmiana przeznaczenia innego niż funkcja zdrowotna
Dopuszczenia:  możliwość wykorzystania terenu pod szpitale, sanatoria, rehabilitacja, opieka społeczna oraz domy opieki społecznej, przychodnie, lecznice, gabinety lekarskie

Przeznaczenie terenu : Tereny usług zdrowia
Symbol: UZ2, UZ3
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10
Geometria dachów: dwuspadowe
Wysokość budynków: 12m
Nakazy: parkingi, ścieżki
Zakazy: zmiana przeznaczenia innego niż funkcja zdrowotna
Dopuszczenia:  możliwość wykorzystania terenu pod szpitale, sanatoria, rehabilitacja, opieka społeczna oraz domy opieki społecznej, przychodnie, lecznice, gabinety lekarskie

Przeznaczenie terenu : Tereny usług edukacji
Symbol:  U18, U21, UE2
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy:  Obowiązująca linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10
Geometria dachów: dwuspadowe
Wysokość budynków: 12
Nakazy: w obrębie działki musi być spełniona minimum jedna z  funkcji edukacji, wychowania i oświaty oraz tereny edukacji przedszkolnej i szkolnej, szkolnictwo podstawowe, edukacji szkolnej ponadpodstawowej, edukacji, wychowania, oświaty i edukacji specjalnej
Zakazy: zakaz tworzenia miejsc parkingowych od strony ulic
Dopuszczenia: możliwość lokalizacji boisk i budowli sportowych,  możliwość lokalizacji placów zabaw dla dzieci.

Przeznaczenie terenu : Tereny usług  edukacji
Symbol: UE1, UE3
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 50%
- min. powierzchnia biologicznie czynna: 20%
Geometria dachów: dwuspadowe
Wysokość budynków: 12
Nakazy: w obrębie działki musi być spełniona minimum jedna z  funkcji edukacji, wychowania i oświaty oraz tereny edukacji przedszkolnej i szkolnej, szkolnictwo podstawowe, edukacji szkolnej ponadpodstawowej, edukacji, wychowania, oświaty i edukacji specjalnej
Zakazy: zakaz tworzenia miejsc parkingowych od strony ulic
Dopuszczenia: możliwość lokalizacji boisk i budowli sportowych,  możliwość lokalizacji placów zabaw dla dzieci.

Przeznaczenie terenu : Tereny usług religijnych
Symbol: UR1, UR2, UR3
Kolor:  czerwony, kreskowany purpurowo
Parametry:
- maks. powierzchnia zabudowy: 60%
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10%
Linia zabudowy: obowiązująca linia zabudowy
Geometria dachów: dwuspadowe
Wysokość budynków: 12
Nakazy: parking i drogi dojazdowe
Zakazy: zakaz stawiania reklam
Dopuszczenia:. kościoły, kaplice, budynki parafialne i związane z kultem religijnym wraz z funkcjami towarzyszącymi oraz placem przed głównym wejściem

Przeznaczenie terenu : Tereny usług  religijnych
Symbol: UR4, UR5
Kolor:  czerwony, kreskowany purpurowo
Linia zabudowy: nieprzekraczalna linia zabudowy
Parametry:
- maks. powierzchnia zabudowy: 60%
- wskaźnik intensywności zabudowy: 1.2
- min. powierzchnia biologicznie czynna: 10%
Geometria dachów: dwuspadowe
Wysokość budynków: 12
Nakazy: parking i drogi dojazdowe
Zakazy: zakaz stawiania reklam
Dopuszczenia:. kościoły, kaplice, budynki parafialne i związane z kultem religijnym wraz z funkcjami towarzyszącymi oraz placem przed głównym wejściem.

Przeznaczenie terenu : Lasy
Symbol: ZL1, ZL2, ZL3 , ZL4
Kolor: Ciemnozielony
Nakazy:  utrzymanie i ochronę drzewostanów dla trwałego zachowania lasów , utrzymanie ciągłości i ochronę istniejących cieków oraz lokalnych ujęć wody
Zakazy: W terenach wyklucza się lokalizację obiektów budowlanych
Dopuszczenia: dopuszczenie prac zabezpieczających i regulacyjnych cieków związanych z ochroną przeciwpowodziową

Przeznaczenie terenu : Tereny zieleni urządzonej
Symbol: ZP1, ZP2, ZP3, ZP4, ZP5, ZP6, ZP7, ZP8, ZP9, ZP10, ZP11, ZP12, ZP 13
Kolor: jasnozielony
Zakazy :zakaz lokalizacji budynków, 
Dopuszczenia : możliwość lokalizacji urządzeń rekreacyjno – wypoczynkowych niekubaturowych,  możliwość realizacji ścieżek rowerowych i szlaków turystycznych,  możliwość sezonowego wykorzystania terenów jako sportowo – rekreacyjne.

Przeznaczenie terenu : Cmentarze
Symbol: ZC1
Kolor: zielony
Nakazy: dla terenu „ZC1” utrzymanie czynnego cmentarza zabytkowego z urządzeniami i obiektami towarzyszącymi
Dopuszczenia:  obiekty kubaturowe związane z przeznaczeniem podstawowym, w tym dom pogrzebowy, kaplica cmentarna, kolumbarium, obiekty, urządzenia i sieci infrastruktury technicznej, urządzenia komunikacji (dojścia, dojazdy) ,zieleń urządzona. 

Przeznaczenie terenu : Tereny wód powierzchniowych
Symbol: WS1, WS2
Kolor: jasnoniebieski
Nakazy:  utrzymanie ciągłości i ochronę istniejących w terenach cieków i urządzeń wodnych wraz z zielenią przybrzeżną niską i wysoką, stanowiącą ich otulinę biologiczną
  obowiązek zachowania naturalnego charakteru brzegów, za wyjątkiem 
Zakazy:   zalesienia terenów lokalizacja obiektów budowlanych
Dopuszczenia:  przeprawy mostowe i kładki piesze ,obiekty, urządzenia i sieci infrastruktury technicznej.

Przeznaczenie terenu : Tereny infrastruktury technicznej

W, dla których ustala się: przeznaczenie podstawowe - tereny infrastruktury technicznej - wodociągi - możliwość lokalizacji sieci i urządzeń wodociągowych.
 K, dla których ustala się: przeznaczenie podstawowe - tereny infrastruktury technicznej - kanalizacja - możliwość lokalizacji sieci i urządzeń kanalizacyjnych. 
Wyznacza sie tereny oznaczone symbolem: 
T, dla których ustala się: 
1) przeznaczenie podstawowe - tereny infrastruktury technicznej - telekomunikacja - ustala się możliwość lokalizacji sieci i urządzeń telekomunikacja
 2) zasady zabudowy i zagospodarowania terenów: dopuszcza się lokalizację stacji bazowych telefonii komórkowych. 
O, dla których ustala się:
 1) przeznaczenie podstawowe - tereny infrastruktury technicznej - gospodarowanie odpadami - ustala się możliwość lokalizacji sieci i urządzeń związanych z gospodarowaniem odpadami tj. składowiska odpadów, kompostownie, sortownie, bazy przeładunkowe odpadów itp.
